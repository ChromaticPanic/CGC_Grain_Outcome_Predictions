# %%
import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from IPython.display import clear_output
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-5cb1cdfb3923> in <module>
#       1 import os
#       2 import sys
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import seaborn as sns
#
# w:\Excel Tips and Macros\ML\env\regions\lib\site-packages\pandas\__init__.py in <module>
#      15 if missing_dependencies:
#      16     raise ImportError(
# ---> 17         "Unable to import required dependencies:\n" + "\n".join(missing_dependencies)
#      18     )
#      19 del hard_dependencies, dependency, missing_dependencies
#
# ImportError: Unable to import required dependencies:
# numpy:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# ...

# %%
dfR1 = pd.read_csv("Regions/region1.csv")
dfR2 = pd.read_csv("Regions/region2.csv")
dfR3 = pd.read_csv("Regions/region3.csv")
dfR4 = pd.read_csv("Regions/region4.csv")
dfR5 = pd.read_csv("Regions/region5.csv")
dfR6 = pd.read_csv("Regions/region6.csv")
dfR7 = pd.read_csv("Regions/region7.csv")
dfR8 = pd.read_csv("Regions/region8.csv")
dfR9 = pd.read_csv("Regions/region9.csv")
dfR10 = pd.read_csv("Regions/region10.csv")

# %%
dfList = [dfR1, dfR2, dfR3, dfR4, dfR5, dfR6, dfR7, dfR8, dfR9]

# %%
for df in dfList:
    df.sort_values(by="YMD")
    df.reset_index()

# %%
dfR10
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, CRnum, MeanTemp, MinTemp, MaxTemp, MeanDewPoint, MinDewPoint, MaxDewPoint, MeanHumidity, MinHumidity, MaxHumidity, MeanPressure, MinPressure, MaxPressure, MeanWindSpeed, MinWindSpeed, MaxWindSpeed, MeanWindChill, MinWindChill, MaxWindChill, TotalPrecip, MeanWindDirection, YMD]
# Index: []
#
# [0 rows x 25 columns]

# %%
fig_, axes_ = plt.subplots(figsize=(30, 20))
sns.scatterplot(data=dfR1, x="YMD", y="MeanTemp", ax=axes_, color="green")
sns.scatterplot(data=dfR1, x="YMD", y="MinTemp", ax=axes_, color="blue")
sns.scatterplot(data=dfR1, x="YMD", y="MaxTemp", ax=axes_, color="orange")
plt.show()

# %%
fig, axes = plt.subplots(3, 3, figsize=(30, 20))

j = 0
k = 0
for df in dfList:
    sns.scatterplot(data=df, x="YMD", y="MeanTemp", ax=axes[j, k], color="green")
    sns.scatterplot(data=df, x="YMD", y="MinTemp", ax=axes[j, k], color="blue")
    sns.scatterplot(data=df, x="YMD", y="MaxTemp", ax=axes[j, k], color="orange")
    k += 1
    if k == 3:
        j += 1
        k = 0


plt.show()

# %%
for df in dfList:
    df["rolavgMean"] = df["MeanTemp"].rolling(window=5).mean()
    df["rolavgMin"] = df["MinTemp"].rolling(window=5).mean()
    df["rolavgMax"] = df["MaxTemp"].rolling(window=5).mean()

# %%
fig, axes = plt.subplots(3, 3, figsize=(30, 20))

j = 0
k = 0
for df in dfList:
    sns.scatterplot(
        data=df, x="YMD", y="rolavgMean", ax=axes[j, k], color="green", size=0.2
    )
    sns.scatterplot(
        data=df, x="YMD", y="rolavgMin", ax=axes[j, k], color="blue", size=0.2
    )
    sns.scatterplot(
        data=df, x="YMD", y="rolavgMax", ax=axes[j, k], color="orange", size=0.2
    )
    k += 1
    if k == 3:
        j += 1
        k = 0


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-bb3932390bc3> in <module>
#      13
#      14
# ---> 15 plt.show()
#
# w:\Excel Tips and Macros\ML\env\regions\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# w:\Excel Tips and Macros\ML\env\regions\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      40             display(
#      41                 figure_manager.canvas.figure,
# ---> 42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      43             )
#      44     finally:
#
# w:\Excel Tips and Macros\ML\env\regions\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
fig, axes = plt.subplots(figsize=(30, 20), subplot_kw={"projection": "3d"})
colors = ["blue", "blue", "blue", "blue", "orange", "blue", "blue", "blue", "blue"]
j = 0
k = 0
for pos in range(0, len(dfList)):
    data = dfList[pos]
    markersize = 1
    if pos == 4:
        markersize = 6
    # axes.scatter(data.index, pos,data["rolavgMean"], color=colors[pos], s=markersize)
    axes.bar(data.index, data["rolavgMean"], zs=pos, zdir="y", color=colors[pos])

    # sns.scatterplot(data = df, x = "YMD", y = "rolavgMin",ax=axes[j,k], color='blue', size=0.2)
    # sns.scatterplot(data = df, x = "YMD", y = "rolavgMax",ax=axes[j,k], color='orange', size=0.2)
    k += 1
    if k == 3:
        j += 1
        k = 0


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-f3d07fac5222> in <module>
#      10         markersize = 6
#      11     # axes.scatter(data.index, pos,data["rolavgMean"], color=colors[pos], s=markersize)
# ---> 12     axes.bar(data.index, data["rolavgMean"], zs=pos,  zdir='y', color=colors[pos])
#      13
#      14     # sns.scatterplot(data = df, x = "YMD", y = "rolavgMin",ax=axes[j,k], color='blue', size=0.2)
#
# w:\Excel Tips and Macros\ML\env\regions\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in bar(self, left, height, zs, zdir, *args, **kwargs)
#    2355         for p, z in zip(patches, zs):
#    2356             vs = art3d._get_patch_verts(p)
# -> 2357             verts += vs.tolist()
#    2358             verts_zs += [z] * len(vs)
#    2359             art3d.patch_2d_to_3d(p, z, zdir)
#
# AttributeError: 'list' object has no attribute 'tolist'
# ...

# %%
fig, axes = plt.subplots(3, 3, figsize=(30, 20))

j = 0
k = 0
for df in dfList:
    sns.scatterplot(data=df, x="YMD", y="TotalPrecip", ax=axes[j, k], color="green")
    # sns.scatterplot(data = df, x = "YMD", y = "rolavgMin",ax=axes[j,k], color='blue')
    # sns.scatterplot(data = df, x = "YMD", y = "rolavgMax",ax=axes[j,k], color='orange')
    k += 1
    if k == 3:
        j += 1
        k = 0


plt.show()
