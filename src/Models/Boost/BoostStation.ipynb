# %% [markdown]
# ## Gradient Boosting Model on Weather Station Data
#
# - Gradient builds an additive model in a forward stage-wise fashion, which allows for the optimization of arbitrary differentiable loss functions.

# %%
# import dependencies
import pandas as pd
import sqlalchemy as sq
import sys, os
import pickle
from imblearn.combine import SMOTEENN
from xgboost import XGBClassifier
from sklearn.ensemble import (  # type: ignore
    GradientBoostingClassifier,
)
from imblearn.ensemble import (  # type: ignore
    RUSBoostClassifier,
)

from sklearn.metrics import (  # type: ignore
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
)

sys.path.append("../../")
os.chdir("../../")
from ModelBuilderMethods import getConn, extractYears, scaleColumns, encodeColumns
from Models.models_ensemble import getBalancedClassifier, getClassifier

# %%
# unlimited line output
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", 500)

# %% [markdown]
# ### <u>**Step 1**</u>: Data Selection
#
# In this step, we would choose the particular data/table, pick attributes from existing tables. Further aggregation/feature engineer can be done here to support the point of the research.
#
# Particular, for this notebook, we grab the following data and merge them (on year, district) into a single table:
# - Monthly weather station
# - ergot data (downgrade)

# %%
# Set the query text
weatherStationQuery = sq.text(
    """
    SELECT * from dataset_cross_monthly_station
"""
)

ergotTargetQuery = sq.text(
    """
    SELECT year, district, downgrade from ergot_sample_feat_eng
"""
)

# %%
conn = getConn("./.env")

stationDf = pd.read_sql(weatherStationQuery, conn)
ergotTargetDf = pd.read_sql(ergotTargetQuery, conn)

conn.close()
del conn

# %%
# merge on year and district
# tempdf = pd.merge(satelliteDf, ergotPrevDf, on=["year", "district"], how="left")
# del satelliteDf
# del ergotPrevDf
# tempdf = satelliteDf
tempdf = stationDf

# merge on year and district
datasetDf = pd.merge(ergotTargetDf, tempdf, on=["year", "district"], how="left")
del ergotTargetDf
del tempdf

# %% [markdown]
# Then, the district number would be categorized using [one-hot encoding](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html) techniques.
#
# One-hot encoding techniques would take input, which is a categorical value. Then, the features are encoded using a one-hot (aka ‘one-of-K’ or ‘dummy’) encoding scheme. This creates a binary column for each category and returns a sparse matrix or dense array (depending on the sparse_output parameter).

# %%
# encode district
datasetDf["district"] = datasetDf["district"].astype("category")

temp = pd.get_dummies(datasetDf["district"], prefix="district", drop_first=True)
datasetDf = pd.concat([datasetDf, temp], axis=1)

datasetDf = datasetDf.drop(columns=["district"])

del temp

# %% [markdown]
# ### <u>**Step 2**</u>: Splitting dataset
#
# - We split the whole dataset into the train/test split. Particularly, split them by year (1995 - 2015 for training, 2016 - 2020 for testing) since this is a time series data.

# %%
# train 1995 - 2015 test 2016 - 2020
trainDf = extractYears(datasetDf, 1995, 2015)
testDf = extractYears(datasetDf, 2016, 2020)
del datasetDf

# %%
# drop year
trainDf = trainDf.drop(columns=["year"])
testDf = testDf.drop(columns=["year"])

# %% [markdown]
# ### <u>**Step 3**</u>: [Balancing the dataset](https://imbalanced-learn.org/stable/)
#
# - Our dataset is unbalanced and can lead to bias when training/testing. Balacing step would help to eliminate the bias of the dataset, thus provide more reliable results.

# %%
# pre balancing check
# print value counts downgrade
print(trainDf["downgrade"].value_counts())
print(testDf["downgrade"].value_counts())
# Out:
# downgrade
# False    122202
# True       2082
# Name: count, dtype: int64
# downgrade
# False    26307
# True      1016
# Name: count, dtype: int64

# %%
# count nan
print(trainDf.isna().sum())
# set nan to 0
trainDf = trainDf.fillna(0)
# Out:
# downgrade                    0
# 1:min_temp_x              1246
# 1:max_temp_x              1246
# 1:mean_temp_x             1246
# 1:min_dew_point_temp      1246
# 1:max_dew_point_temp      1246
# 1:mean_dew_point_temp     1246
# 1:min_humidex             1246
# 1:max_humidex             1246
# 1:mean_humidex            1246
# 1:min_precip              1246
# 1:max_precip              1246
# 1:mean_precip             1246
# 1:min_rel_humid           1246
# 1:max_rel_humid           1246
# 1:mean_rel_humid          1246
# 1:min_stn_press           1246
# 1:max_stn_press           1246
# 1:mean_stn_press          1246
# 1:min_visibility          1246
# 1:max_visibility          1246
# 1:mean_visibility         1246
# 1:max_temp_y              1246
# 1:min_temp_y              1246
# 1:mean_temp_y             1246
# 1:min_total_rain          1246
# 1:max_total_rain          1246
# 1:mean_total_rain         1246
# 1:min_total_snow          1246
# 1:max_total_snow          1246
# 1:mean_total_snow         1246
# 1:min_total_precip        1246
# 1:max_total_precip        1246
# 1:mean_total_precip       1246
# 1:min_snow_on_grnd        1246
# 1:max_snow_on_grnd        1246
# 1:mean_snow_on_grnd       1246
# 2:min_temp_x              1246
# 2:max_temp_x              1246
# 2:mean_temp_x             1246
# 2:min_dew_point_temp      1246
# 2:max_dew_point_temp      1246
# 2:mean_dew_point_temp     1246
# 2:min_humidex             1246
# 2:max_humidex             1246
# 2:mean_humidex            1246
# 2:min_precip              1246
# 2:max_precip              1246
# 2:mean_precip             1246
# 2:min_rel_humid           1246
# 2:max_rel_humid           1246
# 2:mean_rel_humid          1246
# 2:min_stn_press           1246
# 2:max_stn_press           1246
# 2:mean_stn_press          1246
# 2:min_visibility          1246
# 2:max_visibility          1246
# 2:mean_visibility         1246
# 2:max_temp_y              1246
# 2:min_temp_y              1246
# 2:mean_temp_y             1246
# 2:min_total_rain          1246
# 2:max_total_rain          1246
# 2:mean_total_rain         1246
# 2:min_total_snow          1246
# 2:max_total_snow          1246
# 2:mean_total_snow         1246
# 2:min_total_precip        1246
# 2:max_total_precip        1246
# 2:mean_total_precip       1246
# 2:min_snow_on_grnd        1246
# 2:max_snow_on_grnd        1246
# 2:mean_snow_on_grnd       1246
# 3:min_temp_x              1246
# 3:max_temp_x              1246
# 3:mean_temp_x             1246
# 3:min_dew_point_temp      1246
# 3:max_dew_point_temp      1246
# 3:mean_dew_point_temp     1246
# 3:min_humidex             1246
# 3:max_humidex             1246
# 3:mean_humidex            1246
# 3:min_precip              1246
# 3:max_precip              1246
# 3:mean_precip             1246
# 3:min_rel_humid           1246
# 3:max_rel_humid           1246
# 3:mean_rel_humid          1246
# 3:min_stn_press           1246
# 3:max_stn_press           1246
# 3:mean_stn_press          1246
# 3:min_visibility          1246
# 3:max_visibility          1246
# 3:mean_visibility         1246
# 3:max_temp_y              1246
# 3:min_temp_y              1246
# 3:mean_temp_y             1246
# 3:min_total_rain          1246
# 3:max_total_rain          1246
# 3:mean_total_rain         1246
# 3:min_total_snow          1246
# 3:max_total_snow          1246
# 3:mean_total_snow         1246
# 3:min_total_precip        1246
# 3:max_total_precip        1246
# 3:mean_total_precip       1246
# 3:min_snow_on_grnd        1246
# 3:max_snow_on_grnd        1246
# 3:mean_snow_on_grnd       1246
# 4:min_temp_x              1246
# 4:max_temp_x              1246
# 4:mean_temp_x             1246
# 4:min_dew_point_temp      1246
# 4:max_dew_point_temp      1246
# 4:mean_dew_point_temp     1246
# 4:min_humidex             1246
# 4:max_humidex             1246
# 4:mean_humidex            1246
# 4:min_precip              1246
# 4:max_precip              1246
# 4:mean_precip             1246
# 4:min_rel_humid           1246
# 4:max_rel_humid           1246
# 4:mean_rel_humid          1246
# 4:min_stn_press           1246
# 4:max_stn_press           1246
# 4:mean_stn_press          1246
# 4:min_visibility          1246
# 4:max_visibility          1246
# 4:mean_visibility         1246
# 4:max_temp_y              1246
# 4:min_temp_y              1246
# 4:mean_temp_y             1246
# 4:min_total_rain          1246
# 4:max_total_rain          1246
# 4:mean_total_rain         1246
# 4:min_total_snow          1246
# 4:max_total_snow          1246
# 4:mean_total_snow         1246
# 4:min_total_precip        1246
# 4:max_total_precip        1246
# 4:mean_total_precip       1246
# 4:min_snow_on_grnd        1246
# 4:max_snow_on_grnd        1246
# 4:mean_snow_on_grnd       1246
# 5:min_temp_x              1246
# 5:max_temp_x              1246
# 5:mean_temp_x             1246
# 5:min_dew_point_temp      1246
# 5:max_dew_point_temp      1246
# 5:mean_dew_point_temp     1246
# 5:min_humidex             1246
# 5:max_humidex             1246
# 5:mean_humidex            1246
# 5:min_precip              1246
# 5:max_precip              1246
# 5:mean_precip             1246
# 5:min_rel_humid           1246
# 5:max_rel_humid           1246
# 5:mean_rel_humid          1246
# 5:min_stn_press           1246
# 5:max_stn_press           1246
# 5:mean_stn_press          1246
# 5:min_visibility          1246
# 5:max_visibility          1246
# 5:mean_visibility         1246
# 5:max_temp_y              1246
# 5:min_temp_y              1246
# 5:mean_temp_y             1246
# 5:min_total_rain          1246
# 5:max_total_rain          1246
# 5:mean_total_rain         1246
# 5:min_total_snow          1246
# 5:max_total_snow          1246
# 5:mean_total_snow         1246
# 5:min_total_precip        1246
# 5:max_total_precip        1246
# 5:mean_total_precip       1246
# 5:min_snow_on_grnd        1246
# 5:max_snow_on_grnd        1246
# 5:mean_snow_on_grnd       1246
# 6:min_temp_x              1246
# 6:max_temp_x              1246
# 6:mean_temp_x             1246
# 6:min_dew_point_temp      1246
# 6:max_dew_point_temp      1246
# 6:mean_dew_point_temp     1246
# 6:min_humidex             1246
# 6:max_humidex             1246
# 6:mean_humidex            1246
# 6:min_precip              1246
# 6:max_precip              1246
# 6:mean_precip             1246
# 6:min_rel_humid           1246
# 6:max_rel_humid           1246
# 6:mean_rel_humid          1246
# 6:min_stn_press           1246
# 6:max_stn_press           1246
# 6:mean_stn_press          1246
# 6:min_visibility          1246
# 6:max_visibility          1246
# 6:mean_visibility         1246
# 6:max_temp_y              1246
# 6:min_temp_y              1246
# 6:mean_temp_y             1246
# 6:min_total_rain          1246
# 6:max_total_rain          1246
# 6:mean_total_rain         1246
# 6:min_total_snow          1246
# 6:max_total_snow          1246
# 6:mean_total_snow         1246
# 6:min_total_precip        1246
# 6:max_total_precip        1246
# 6:mean_total_precip       1246
# 6:min_snow_on_grnd        1246
# 6:max_snow_on_grnd        1246
# 6:mean_snow_on_grnd       1246
# 7:min_temp_x              1246
# 7:max_temp_x              1246
# 7:mean_temp_x             1246
# 7:min_dew_point_temp      1246
# 7:max_dew_point_temp      1246
# 7:mean_dew_point_temp     1246
# 7:min_humidex             1246
# 7:max_humidex             1246
# 7:mean_humidex            1246
# 7:min_precip              1246
# 7:max_precip              1246
# 7:mean_precip             1246
# 7:min_rel_humid           1246
# 7:max_rel_humid           1246
# 7:mean_rel_humid          1246
# 7:min_stn_press           1246
# 7:max_stn_press           1246
# 7:mean_stn_press          1246
# 7:min_visibility          1246
# 7:max_visibility          1246
# 7:mean_visibility         1246
# 7:max_temp_y              1246
# 7:min_temp_y              1246
# 7:mean_temp_y             1246
# 7:min_total_rain          1246
# 7:max_total_rain          1246
# 7:mean_total_rain         1246
# 7:min_total_snow          1246
# 7:max_total_snow          1246
# 7:mean_total_snow         1246
# 7:min_total_precip        1246
# 7:max_total_precip        1246
# 7:mean_total_precip       1246
# 7:min_snow_on_grnd        1246
# 7:max_snow_on_grnd        1246
# 7:mean_snow_on_grnd       1246
# 8:min_temp_x              1246
# 8:max_temp_x              1246
# 8:mean_temp_x             1246
# 8:min_dew_point_temp      1246
# 8:max_dew_point_temp      1246
# 8:mean_dew_point_temp     1246
# 8:min_humidex             1246
# 8:max_humidex             1246
# 8:mean_humidex            1246
# 8:min_precip              1246
# 8:max_precip              1246
# 8:mean_precip             1246
# 8:min_rel_humid           1246
# 8:max_rel_humid           1246
# 8:mean_rel_humid          1246
# 8:min_stn_press           1246
# 8:max_stn_press           1246
# 8:mean_stn_press          1246
# 8:min_visibility          1246
# 8:max_visibility          1246
# 8:mean_visibility         1246
# 8:max_temp_y              1246
# 8:min_temp_y              1246
# 8:mean_temp_y             1246
# 8:min_total_rain          1246
# 8:max_total_rain          1246
# 8:mean_total_rain         1246
# 8:min_total_snow          1246
# 8:max_total_snow          1246
# 8:mean_total_snow         1246
# 8:min_total_precip        1246
# 8:max_total_precip        1246
# 8:mean_total_precip       1246
# 8:min_snow_on_grnd        1246
# 8:max_snow_on_grnd        1246
# 8:mean_snow_on_grnd       1246
# 9:min_temp_x              1246
# 9:max_temp_x              1246
# 9:mean_temp_x             1246
# 9:min_dew_point_temp      1246
# 9:max_dew_point_temp      1246
# 9:mean_dew_point_temp     1246
# 9:min_humidex             1246
# 9:max_humidex             1246
# 9:mean_humidex            1246
# 9:min_precip              1246
# 9:max_precip              1246
# 9:mean_precip             1246
# 9:min_rel_humid           1246
# 9:max_rel_humid           1246
# 9:mean_rel_humid          1246
# 9:min_stn_press           1246
# 9:max_stn_press           1246
# 9:mean_stn_press          1246
# 9:min_visibility          1246
# 9:max_visibility          1246
# 9:mean_visibility         1246
# 9:max_temp_y              1246
# 9:min_temp_y              1246
# 9:mean_temp_y             1246
# 9:min_total_rain          1246
# 9:max_total_rain          1246
# 9:mean_total_rain         1246
# 9:min_total_snow          1246
# 9:max_total_snow          1246
# 9:mean_total_snow         1246
# 9:min_total_precip        1246
# 9:max_total_precip        1246
# 9:mean_total_precip       1246
# 9:min_snow_on_grnd        1246
# 9:max_snow_on_grnd        1246
# 9:mean_snow_on_grnd       1246
# 10:min_temp_x             1246
# 10:max_temp_x             1246
# 10:mean_temp_x            1246
# 10:min_dew_point_temp     1246
# 10:max_dew_point_temp     1246
# 10:mean_dew_point_temp    1246
# 10:min_humidex            1246
# 10:max_humidex            1246
# 10:mean_humidex           1246
# 10:min_precip             1246
# 10:max_precip             1246
# 10:mean_precip            1246
# 10:min_rel_humid          1246
# 10:max_rel_humid          1246
# 10:mean_rel_humid         1246
# 10:min_stn_press          1246
# 10:max_stn_press          1246
# 10:mean_stn_press         1246
# 10:min_visibility         1246
# 10:max_visibility         1246
# 10:mean_visibility        1246
# 10:max_temp_y             1246
# 10:min_temp_y             1246
# 10:mean_temp_y            1246
# 10:min_total_rain         1246
# 10:max_total_rain         1246
# 10:mean_total_rain        1246
# 10:min_total_snow         1246
# 10:max_total_snow         1246
# 10:mean_total_snow        1246
# 10:min_total_precip       1246
# 10:max_total_precip       1246
# 10:mean_total_precip      1246
# 10:min_snow_on_grnd       1246
# 10:max_snow_on_grnd       1246
# 10:mean_snow_on_grnd      1246
# 11:min_temp_x             1246
# 11:max_temp_x             1246
# 11:mean_temp_x            1246
# 11:min_dew_point_temp     1246
# 11:max_dew_point_temp     1246
# 11:mean_dew_point_temp    1246
# 11:min_humidex            1246
# 11:max_humidex            1246
# 11:mean_humidex           1246
# 11:min_precip             1246
# 11:max_precip             1246
# 11:mean_precip            1246
# 11:min_rel_humid          1246
# 11:max_rel_humid          1246
# 11:mean_rel_humid         1246
# 11:min_stn_press          1246
# 11:max_stn_press          1246
# 11:mean_stn_press         1246
# 11:min_visibility         1246
# 11:max_visibility         1246
# 11:mean_visibility        1246
# 11:max_temp_y             1246
# 11:min_temp_y             1246
# 11:mean_temp_y            1246
# 11:min_total_rain         1246
# 11:max_total_rain         1246
# 11:mean_total_rain        1246
# 11:min_total_snow         1246
# 11:max_total_snow         1246
# 11:mean_total_snow        1246
# 11:min_total_precip       1246
# 11:max_total_precip       1246
# 11:mean_total_precip      1246
# 11:min_snow_on_grnd       1246
# 11:max_snow_on_grnd       1246
# 11:mean_snow_on_grnd      1246
# 12:min_temp_x             1246
# 12:max_temp_x             1246
# 12:mean_temp_x            1246
# 12:min_dew_point_temp     1246
# 12:max_dew_point_temp     1246
# 12:mean_dew_point_temp    1246
# 12:min_humidex            1246
# 12:max_humidex            1246
# 12:mean_humidex           1246
# 12:min_precip             1246
# 12:max_precip             1246
# 12:mean_precip            1246
# 12:min_rel_humid          1246
# 12:max_rel_humid          1246
# 12:mean_rel_humid         1246
# 12:min_stn_press          1246
# 12:max_stn_press          1246
# 12:mean_stn_press         1246
# 12:min_visibility         1246
# 12:max_visibility         1246
# 12:mean_visibility        1246
# 12:max_temp_y             1246
# 12:min_temp_y             1246
# 12:mean_temp_y            1246
# 12:min_total_rain         1246
# 12:max_total_rain         1246
# 12:mean_total_rain        1246
# 12:min_total_snow         1246
# 12:max_total_snow         1246
# 12:mean_total_snow        1246
# 12:min_total_precip       1246
# 12:max_total_precip       1246
# 12:mean_total_precip      1246
# 12:min_snow_on_grnd       1246
# 12:max_snow_on_grnd       1246
# 12:mean_snow_on_grnd      1246
# district_4602                0
# district_4603                0
# district_4604                0
# district_4605                0
# district_4606                0
# district_4607                0
# district_4608                0
# district_4609                0
# district_4610                0
# district_4611                0
# district_4612                0
# district_4710                0
# district_4711                0
# district_4720                0
# district_4721                0
# district_4730                0
# district_4731                0
# district_4732                0
# district_4733                0
# district_4740                0
# district_4741                0
# district_4750                0
# district_4751                0
# district_4760                0
# district_4761                0
# district_4770                0
# district_4771                0
# district_4780                0
# district_4781                0
# district_4790                0
# district_4791                0
# district_4810                0
# district_4820                0
# district_4830                0
# district_4840                0
# district_4850                0
# district_4860                0
# district_4870                0
# dtype: int64

# %%
balancer = SMOTEENN(sampling_strategy=1, random_state=42)
balancedTrainDfX, balancedTrainDfY = balancer.fit_resample(
    trainDf.drop(columns="downgrade"), trainDf["downgrade"]
)

# %%
# post balancing check
# print value counts downgrade
print(balancedTrainDfY.value_counts())
# Out:
# downgrade
# False    115179
# True      23757
# Name: count, dtype: int64

# %% [markdown]
# ### <u>**Step 4**</u>: Regularization / Normalization
# some blurb about scalers
#
# 1. [MinMaxScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)
# 2. [MaxAbsScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MaxAbsScaler.html)
# 3. [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
# 4. [RobustScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)
# 5. [Normalizer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.Normalizer.html)
# 6. [PowerTransformer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PowerTransformer.html)
# 7. [QuantileTransformer](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.QuantileTransformer.html)

# %%
# df = pd.DataFrame()
# scaled = scaleColumns(df, ['max_temp'], None, 1)

# %%
def printMetrics(model_name, y_true, y_pred):
    print(model_name)
    print("Accuracy: ", accuracy_score(y_true, y_pred))
    print("Precision: ", precision_score(y_true, y_pred))
    print("Recall: ", recall_score(y_true, y_pred))
    print("F1: ", f1_score(y_true, y_pred))
    print("ROC AUC: ", roc_auc_score(y_true, y_pred))
    print("Classification Report: \n", classification_report(y_true, y_pred))
    print()

# %% [markdown]
# ### <u>**Step 5**</u>: Gradient Boosting Classifier Model

# %%
ESTIMATORS = 400
DEPTH = 40
CORES = -1
MINSPLSPLIT = 8
MINSAMPLELEAF = 4

gradient_boosting_model = GradientBoostingClassifier(
    n_estimators=ESTIMATORS,
    random_state=42,
    max_depth=DEPTH,
    verbose=1,
    n_iter_no_change=200,
)
balanced_gradient_boosting_model = GradientBoostingClassifier(
    n_estimators=ESTIMATORS,
    random_state=42,
    max_depth=DEPTH,
    verbose=1,
    n_iter_no_change=200,
)
rusboost_model = RUSBoostClassifier(
    n_estimators=ESTIMATORS, random_state=42, sampling_strategy=0.5
)
balanced_rusboost_model = RUSBoostClassifier(
    n_estimators=ESTIMATORS, random_state=42, sampling_strategy=0.5
)
xgboost_model = XGBClassifier(
    n_estimators=ESTIMATORS, random_state=42, max_depth=DEPTH, verbosity=1, n_jobs=CORES
)
balanced_xgboost_model = XGBClassifier(
    n_estimators=ESTIMATORS, random_state=42, max_depth=DEPTH, verbosity=1, n_jobs=CORES
)

# %%
gradient_boosting_model.fit(trainDf.drop(columns="downgrade"), trainDf["downgrade"])
balanced_gradient_boosting_model.fit(balancedTrainDfX, balancedTrainDfY)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.1563           76.55m
#          2           0.1517           76.15m
#          3           0.1484           76.18m
#          4           0.1459           76.06m
#          5           0.1438           75.35m
#          6           0.1422           74.86m
#          7           0.1408           74.84m
#          8           0.1397           73.82m
#          9           0.1387           72.84m
#         10           0.1378           72.05m
#         20           0.1336           66.49m
#         30           0.1324           62.26m
#         40           0.1320           57.46m
#         50           0.1318           77.18m
#         60           0.1318           77.62m
#         70           0.1318           75.61m
#         80           0.1317           72.45m
#         90           0.1317           69.56m
#        100           0.1317           66.95m
#        200           0.1317           35.53m
#       Iter       Train Loss   Remaining Time
#          1           0.7259          103.64m
#          2           0.6096          109.14m
#          3           0.5234          107.32m
#          4           0.4551          106.02m
#          5           0.3990          105.30m
#          6           0.3518          104.78m
#          7           0.3115          105.81m
#          8           0.2768          105.09m
#          9           0.2466          104.82m
#         10           0.2201          104.20m
#         20           0.0754          100.90m
#         30           0.0271           97.14m
#         40           0.0099           93.88m
#         50           0.0036           90.86m
#         60           0.0013           88.00m
#         70           0.0005           85.23m
#         80           0.0002          101.89m
#         90           0.0001          106.70m
#        100           0.0000          107.57m
#        200           0.0000           62.12m
#        300           0.0000           20.71m
# GradientBoostingClassifier(max_depth=40, n_estimators=400, n_iter_no_change=200,
#                            random_state=42, verbose=1)

# %% [markdown]
# eval procedure

# %%
rusboost_model.fit(trainDf.drop(columns="downgrade"), trainDf["downgrade"])
balanced_rusboost_model.fit(balancedTrainDfX, balancedTrainDfY)
# Out:
# RUSBoostClassifier(n_estimators=400, random_state=42, sampling_strategy=0.5)

# %%
xgboost_model.fit(trainDf.drop(columns="downgrade"), trainDf["downgrade"])
balanced_xgboost_model.fit(balancedTrainDfX, balancedTrainDfY)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=40, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=400, n_jobs=-1, num_parallel_tree=None,
#               predictor=None, random_state=42, ...)

# %%
# set nan to 0
testDf = testDf.fillna(0)

# %%
# get predictions

predictions_gradient_boosting = gradient_boosting_model.predict(
    testDf.drop(columns="downgrade")
)
predictions_balanced_gradient_boosting = balanced_gradient_boosting_model.predict(
    testDf.drop(columns="downgrade")
)
predictions_rusboost = rusboost_model.predict(testDf.drop(columns="downgrade"))
predictions_balanced_rusboost = balanced_rusboost_model.predict(
    testDf.drop(columns="downgrade")
)
predictions_xgboost = xgboost_model.predict(testDf.drop(columns="downgrade"))
predictions_balanced_xgboost = balanced_xgboost_model.predict(
    testDf.drop(columns="downgrade")
)

# %%
print(pd.DataFrame(predictions_gradient_boosting).value_counts())
print(pd.DataFrame(predictions_balanced_gradient_boosting).value_counts())
print(pd.DataFrame(predictions_rusboost).value_counts())
print(pd.DataFrame(predictions_balanced_rusboost).value_counts())
print(pd.DataFrame(predictions_xgboost).value_counts())
print(pd.DataFrame(predictions_balanced_xgboost).value_counts())
# Out:
# False    27323
# Name: count, dtype: int64
# False    16911
# True     10412
# Name: count, dtype: int64
# False    23040
# True      4283
# Name: count, dtype: int64
# False    24714
# True      2609
# Name: count, dtype: int64
# 0    27323
# Name: count, dtype: int64
# 0    26222
# 1     1101
# Name: count, dtype: int64

# %%
# get accuracy precision recall f1 roc_auc
printMetrics(
    "sk GB imbalanced train set", testDf["downgrade"], predictions_gradient_boosting
)
printMetrics(
    "imb GB balanced train set",
    testDf["downgrade"],
    predictions_balanced_gradient_boosting,
)
printMetrics("sk RUS imbalanced train set", testDf["downgrade"], predictions_rusboost)
printMetrics(
    "imb RUS balanced train set", testDf["downgrade"], predictions_balanced_rusboost
)
printMetrics("sk XGB imbalanced train set", testDf["downgrade"], predictions_xgboost)
printMetrics(
    "imb XGB balanced train set", testDf["downgrade"], predictions_balanced_xgboost
)
# Out:
# sk GB imbalanced train set
# Accuracy:  0.9628152106284082
# Precision:  0.0
# Recall:  0.0
# F1:  0.0
# ROC AUC:  0.5
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98     26307
#         True       0.00      0.00      0.00      1016
#
#     accuracy                           0.96     27323
#    macro avg       0.48      0.50      0.49     27323
# weighted avg       0.93      0.96      0.94     27323
#
#
# imb GB balanced train set
# Accuracy:  0.6084617355341654
# Precision:  0.03505570495582021
# Recall:  0.359251968503937
# F1:  0.06387819390969549
# ROC AUC:  0.488669204687594
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      0.62      0.75     26307
#         True       0.04      0.36      0.06      1016
#
#     accuracy                           0.61     27323
#    macro avg       0.50      0.49      0.41     27323
# weighted avg       0.93      0.61      0.73     27323
#
#
# sk RUS imbalanced train set
# Accuracy:  0.82575119862387
# Precision:  0.06280644408125145
# Recall:  0.26476377952755903
# F1:  0.10152859030005659
# ROC AUC:  0.556090408409007
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.97      0.85      0.90     26307
#         True       0.06      0.26      0.10      1016
#
#     accuracy                           0.83     27323
#    macro avg       0.52      0.56      0.50     27323
# weighted avg       0.93      0.83      0.87     27323
#
#
# imb RUS balanced train set
# Accuracy:  0.8731837645939319
# Precision:  0.030663089306247605
# Recall:  0.07874015748031496
# F1:  0.04413793103448276
# ROC AUC:  0.4913030243439892
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      0.90      0.93     26307
#         True       0.03      0.08      0.04      1016
#
#     accuracy                           0.87     27323
#    macro avg       0.50      0.49      0.49     27323
# weighted avg       0.93      0.87      0.90     27323
#
#
# sk XGB imbalanced train set
# Accuracy:  0.9628152106284082
# Precision:  0.0
# Recall:  0.0
# F1:  0.0
# ROC AUC:  0.5
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98     26307
#         True       0.00      0.00      0.00      1016
#
#     accuracy                           0.96     27323
#    macro avg       0.48      0.50      0.49     27323
# weighted avg       0.93      0.96      0.94     27323
#
#
# imb XGB balanced train set
# Accuracy:  0.9258134172675035
# Precision:  0.04087193460490463
# Recall:  0.04429133858267716
# F1:  0.042512990080302314
# ROC AUC:  0.5020749656763311
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      0.96      0.96     26307
#         True       0.04      0.04      0.04      1016
#
#     accuracy                           0.93     27323
#    macro avg       0.50      0.50      0.50     27323
# weighted avg       0.93      0.93      0.93     27323
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# print model performance metrics on test data
