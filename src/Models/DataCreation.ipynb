# %%
from matplotlib import pyplot as plt  # type: ignore
from matplotlib import cm, colors  # type: ignore
from dotenv import load_dotenv
import geopandas as gpd  # type: ignore
import sqlalchemy as sq
import pandas as pd  # type: ignore
import numpy as np
import os, sys

sys.path.append("../")
from Shared.DataService import DataService

from Datasets.DataCreation import getDatasetV1, getWeatherData_v1, getDatasetV2

# %%
load_dotenv()
PG_DB = os.getenv("POSTGRES_DB")
PG_ADDR = os.getenv("POSTGRES_ADDR")
PG_PORT = os.getenv("POSTGRES_PORT")
PG_USER = os.getenv("POSTGRES_USER")
PG_PW = os.getenv("POSTGRES_PW")

if (
    PG_DB is None
    or PG_ADDR is None
    or PG_PORT is None
    or PG_USER is None
    or PG_PW is None
):
    raise ValueError("Environment variables not set")

# connecting to database
db = DataService(PG_DB, PG_ADDR, int(PG_PORT), PG_USER, PG_PW)
conn = db.connect()

# %%
dataset_v1 = getDatasetV1();
dataset_v1
# Out:
#       year  district  mean_total_precip  mean_snow_on_grnd  mean_temp  \
# 0     1995      4860           1.189348           6.005903   0.451735
# 1     1995      4810           0.871078           0.860822   4.239744
# 2     1995      4840           0.790694           3.564932   1.628772
# 3     1995      4830           1.299196           1.054999   3.060292
# 4     1995      4731           0.908037           0.010959   2.796575
# ...    ...       ...                ...                ...        ...
# 1059  2022      4605           1.151507          14.356164   0.777808
# 1060  2022      4720           1.097808           6.519178   2.653288
# 1061  2022      4611           2.099726           5.945205   1.931507
# 1062  2022      4751           1.102466           5.210959   1.386849
# 1063  2022      4750           1.163562           4.393151   1.238356
#
#       mean_total_rain  mean_total_snow  has_ergot
# 0            0.529384         0.303979      False
# 1            0.328105         0.116534      False
# 2            0.250507         0.155237       True
# 3            0.332711         0.135583       True
# 4            0.078265         0.010502       True
# ...               ...              ...        ...
# 1059         0.000000         0.000000       True
# 1060         0.000000         0.000000       True
# 1061         0.000000         0.000000       True
# 1062         0.000000         0.000000       True
# 1063         0.000000         0.000000       True
#
# [1064 rows x 8 columns]

# %%
dataset_v2 = getDatasetV2()
dataset_v2
# Out:
#       year  district  has_ergot  soil_moisture_mean  avg_percnt_coarse_frag  \
# 0     1995      4810      False            0.185436                0.814580
# 1     1995      4820      False            0.191228                0.690591
# 2     1995      4830       True            0.211881                2.668642
# 3     1995      4840       True            0.176848                0.987636
# 4     1995      4850       True            0.203983                1.485562
# ...    ...       ...        ...                 ...                     ...
# 1021  2021      4761       True            0.154131                0.118077
# 1022  2021      4771      False            0.162961                0.118784
# 1023  2021      4790       True            0.174330                0.056801
# 1024  2021      4791       True            0.181714                0.217503
# 1025  2021      4610      False            0.243173                0.150126
#
#       avg_total_sand  avg_total_silt  avg_total_clay  avg_percnt_carbon  \
# 0          10.151682        8.183592        5.607801           0.194739
# 1          10.608514       10.460087        7.514317           0.259585
# 2           8.133952        9.788505        5.406994           1.183456
# 3          11.830575        8.842322        6.326134           0.370187
# 4           8.544626        9.731278        6.401610           1.687239
# ...              ...             ...             ...                ...
# 1021        8.920439        4.103344        3.274963           0.190542
# 1022        6.726867        5.293417        4.101292           0.186080
# 1023        7.128145        3.503438        2.247279           0.672719
# 1024        7.369429        4.277239        2.733913           0.726738
# 1025        3.166677        0.953836        1.493130           2.350164
#
#       avg_calcium_ph  ...  avg_elec_cond  avg_percnt_wood  \
# 0           1.715932  ...       0.333493        -2.156050
# 1           2.069420  ...       0.304799        -2.574322
# 2           1.676892  ...      -0.041658        -2.164751
# 3           1.794557  ...       0.212867        -2.425518
# 4           1.706077  ...       0.019440        -2.115329
# ...              ...  ...            ...              ...
# 1021        1.161622  ...       0.161317        -1.467649
# 1022        1.129573  ...       0.151303        -1.450942
# 1023        0.970374  ...       0.049250        -1.226463
# 1024        1.007922  ...       0.048326        -1.354835
# 1025        0.723625  ...       0.012625        -0.619428
#
#       avg_water_holding_cap  avg_land_area  avg_water_area  mean_total_precip  \
# 0                  0.905770   12770.267922      221.887176           0.871078
# 1                  1.137961   13087.528444      192.432890           0.886408
# 2                  1.066667   17233.988072      148.774415           1.299196
# 3                  1.020778   15958.245978      453.479246           0.790694
# 4                  1.200398   17628.060624      450.470480           1.039705
# ...                     ...            ...             ...                ...
# 1021               0.590178    8125.335152      169.335057           0.427420
# 1022               0.635367    8475.354085      180.424326           0.572603
# 1023               0.535738    3952.809369      121.409724           0.668708
# 1024               0.614992    6413.852678      213.362075           0.620091
# 1025               0.475236    7266.866818      868.720543           1.231918
#
#       mean_snow_on_grnd  mean_temp  mean_total_rain  mean_total_snow
# 0              0.860822   4.239744         0.328105         0.116534
# 1              0.366132   4.111654         0.179473         0.057567
# 2              1.054999   3.060292         0.332711         0.135583
# 3              3.564932   1.628772         0.250507         0.155237
# 4              3.333659   2.373816         0.531016         0.196111
# ...                 ...        ...              ...              ...
# 1021           4.576484   3.685183         0.000000         0.000000
# 1022           2.476712   2.451233         0.000000         0.000000
# 1023           6.132192   2.210201         0.087096         0.008347
# 1024           5.756849   2.101918         0.000000         0.000000
# 1025           5.357991   4.600457         0.000000         0.000000
#
# [1026 rows x 26 columns]
